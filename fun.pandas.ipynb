# %%
import numpy as np

# %%
import pandas as pd

# %%
df= pd.read_csv('Stress_Dataset.csv')

# %%
df
# Out:
#      Gender  Age  Have you recently experienced stress in your life?  \
# 0         0   20                                                  3
# 1         0   20                                                  2
# 2         0   20                                                  5
# 3         1   20                                                  3
# 4         0   20                                                  3
# ..      ...  ...                                                ...
# 838       0   21                                                  3
# 839       1   19                                                  3
# 840       1   19                                                  4
# 841       0   20                                                  5
# 842       0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# ...

# %%
df.head()
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
# 3       1   20                                                  3
# 4       0   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# ...

# %%
df.tail(2)
# Out:
#      Gender  Age  Have you recently experienced stress in your life?  \
# 841       0   20                                                  5
# 842       0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 841                                                  4
# 842                                                  3
#
#      Have you been dealing with anxiety or tension recently?  \
# 841                                                  3
# 842                                                  1
#
#      Do you face any sleep problems or difficulties falling asleep?  \
# 841                                                  4
# 842                                                  3
#
#      Have you been dealing with anxiety or tension recently?.1  \
# 841                                                  3
# 842                                                  2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 26 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Gender                                                                843 non-null    int64
#  1   Age                                                                   843 non-null    int64
#  2   Have you recently experienced stress in your life?                    843 non-null    int64
#  3   Have you noticed a rapid heartbeat or palpitations?                   843 non-null    int64
#  4   Have you been dealing with anxiety or tension recently?               843 non-null    int64
#  5   Do you face any sleep problems or difficulties falling asleep?        843 non-null    int64
# ...

# %%
df.describe()
# Out:
#            Gender         Age  \
# count  843.000000  843.000000
# mean     0.349941   20.071174
# std      0.477234    5.429502
# min      0.000000   14.000000
# 25%      0.000000   19.000000
# 50%      0.000000   19.000000
# 75%      1.000000   20.000000
# max      1.000000  100.000000
#
#        Have you recently experienced stress in your life?  \
# count                                         843.000000
# mean                                            2.997628
# std                                             1.134639
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Have you noticed a rapid heartbeat or palpitations?  \
# count                                         843.000000
# ...

# %% [markdown]
# # fet rows and col

# %%
df['Age']
# Out:
# 0      20
# 1      20
# 2      20
# 3      20
# 4      20
#        ..
# 838    21
# 839    19
# 840    19
# 841    20
# 842    19
# Name: Age, Length: 843, dtype: int64

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df[['Age','Gender']]
# Out:
#      Age  Gender
# 0     20       0
# 1     20       0
# 2     20       0
# 3     20       1
# 4     20       0
# ..   ...     ...
# 838   21       0
# 839   19       1
# 840   19       1
# 841   20       0
# 842   19       0
#
# [843 rows x 2 columns]

# %% [markdown]
# # fet row method

# %%
data= pd.read_csv('student.csv')

# %%
data.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda                   -1199    (496)978-3969x58947
# ...

# %%
data.iloc[0]
# Out:
# Index                                         1
# Customer Id                     DD37Cf93aecA6Dc
# First Name                               Sheryl
# Last Name                                Baxter
# Company                         Rasmussen Group
# City                               East Leonard
# Country                                   Chile
# Phone 1                            229.077.5154
# Phone 2                        397.884.0519x718
# Email                  zunigavanessa@smith.info
# Subscription Date                     8/24/2020
# Website              http://www.stephenson.com/
# Name: 0, dtype: object

# %%
data.iloc[1]
# Out:
# Index                                    2
# Customer Id                1Ef7b82A4CAAD10
# First Name                         Preston
# Last Name                           Lozano
# Company                        Vega-Gentry
# City                     East Jimmychester
# Country                           Djibouti
# Phone 1                         5153435776
# Phone 2                   686-620-1820x944
# Email                      vmata@colon.com
# Subscription Date                4/23/2021
# Website              http://www.hobbs.com/
# Name: 1, dtype: object

# %%
data.iloc[2:4]
# Out:
#    Index      Customer Id First Name Last Name  \
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
#
#                            Company           City              Country  \
# 2                    Murillo-Perry  Isabelborough  Antigua and Barbuda
# 3  Dominguez, Mcmillan and Donovan     Bensonview   Dominican Republic
#
#                   Phone 1              Phone 2                        Email  \
# 2                   -1199  (496)978-3969x58947          beckycarr@hogan.com
# 3  001-808-617-6467x12895                -9892  stanleyblackwell@benson.org
#
#   Subscription Date                     Website
# 2         3/25/2020    http://www.lawrence.com/
# 3          6/2/2020  http://www.good-lyons.com/

# %%
data.iloc[2:6:2]
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 2      3  6F94879bDAfE5a6        Roy     Berry             Murillo-Perry
# 4      5  053d585Ab6b3159     Joanna    Bender  Martin, Lang and Andrade
#
#              City                     Country                 Phone 1  \
# 2   Isabelborough         Antigua and Barbuda                   -1199
# 4  West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                    Email Subscription Date  \
# 2    (496)978-3969x58947      beckycarr@hogan.com         3/25/2020
# 4  001-199-446-3860x3486  colinalvarado@miles.net         4/17/2021
#
#                        Website
# 2     http://www.lawrence.com/
# 4  https://goodwin-ingram.com/

# %% [markdown]
# # faning method

# %%
data.iloc[[2,5,7]]
# Out:
#    Index      Customer Id First Name Last Name                       Company  \
# 2      3  6F94879bDAfE5a6        Roy     Berry                 Murillo-Perry
# 5      6  2d08FB17EE273F4      Aimee     Downs                  Steele Group
# 7      8  0e04AFde9f225dE      Brett    Mullen  Sanford, Davenport and Giles
#
#             City                 Country               Phone 1  \
# 2  Isabelborough     Antigua and Barbuda                 -1199
# 5  Chavezborough  Bosnia and Herzegovina   (283)437-3886x88321
# 7        Kimport                Bulgaria  001-583-352-7197x297
#
#                Phone 2                Email Subscription Date  \
# 2  (496)978-3969x58947  beckycarr@hogan.com         3/25/2020
# 5         999-728-1637  louis27@gilbert.com         2/25/2020
# 7     001-333-145-0369      asnow@colon.com         4/12/2021
#
#                        Website
# 2     http://www.lawrence.com/
# 5       http://www.berger.net/
# 7  https://hammond-ramsey.com/

# %% [markdown]
# # fet col

# %%
data.iloc[:,2:5]
# Out:
#    First Name Last Name                          Company
# 0      Sheryl    Baxter                  Rasmussen Group
# 1     Preston    Lozano                      Vega-Gentry
# 2         Roy     Berry                    Murillo-Perry
# 3       Linda     Olsen  Dominguez, Mcmillan and Donovan
# 4      Joanna    Bender         Martin, Lang and Andrade
# ..        ...       ...                              ...
# 95       Karl     Greer                        Carey LLC
# 96       Lynn  Atkinson            Ware, Burns and Oneal
# 97       Fred    Guerra                    Schmitt-Jones
# 98     Yvonne    Farmer               Fitzgerald-Harrell
# 99   Clarence    Haynes               Le, Nash and Cross
#
# [100 rows x 3 columns]

# %%
data.iloc[:,[2,3,7]]
# Out:
#    First Name Last Name                 Phone 1
# 0      Sheryl    Baxter            229.077.5154
# 1     Preston    Lozano              5153435776
# 2         Roy     Berry                   -1199
# 3       Linda     Olsen  001-808-617-6467x12895
# 4      Joanna    Bender  001-234-203-0635x76146
# ..        ...       ...                     ...
# 95       Karl     Greer     (188)169-1674x58692
# 96       Lynn  Atkinson                   -3769
# 97       Fred    Guerra    +1-753-067-8419x7170
# 98     Yvonne    Farmer           (530)311-9786
# 99   Clarence    Haynes           (753)813-6941
#
# [100 rows x 3 columns]

# %%
data.iloc[-1]
# Out:
# Index                                              100
# Customer Id                            2354a0E336A91A1
# First Name                                    Clarence
# Last Name                                       Haynes
# Company                             Le, Nash and Cross
# City                                         Judymouth
# Country                                       Honduras
# Phone 1                                  (753)813-6941
# Phone 2                                   783.639.1472
# Email                           colleen91@faulkner.biz
# Subscription Date                            3/11/2020
# Website              http://www.hatfield-saunders.net/
# Name: 99, dtype: object

# %%
data
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
mask =data['City'] == 'East Leonard'

# %%
mask
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: City, Length: 100, dtype: bool

# %%
data[mask]
# Out:
#    Index      Customer Id First Name Last Name          Company          City  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group  East Leonard
#
#   Country       Phone 1           Phone 2                     Email  \
# 0   Chile  229.077.5154  397.884.0519x718  zunigavanessa@smith.info
#
#   Subscription Date                     Website
# 0         8/24/2020  http://www.stephenson.com/

# %%
data[mask].shape
# Out:
# (1, 12)

# %%
def myfun(City):
    mask =data['City'] == 'East Leonard'
    return data[mask].shape
myfun('lsabelborough')
# Out:
# (1, 12)

# %%
st= pd.read_csv('fist.dataset.csv')

# %%
st.head(5)
# Out:
#    unmaed  0  gpa      iq  plament
# 0       0  0  6.8  .123.0        1
# 1       1  1  5.9  .160.0        0
# 2       2  2  5.3  .120.0        0
# 3       3  3  7.4  .132.0        1
# 4       4  4  5.8  .142.0        0

# %%
mask1 =st['gpa']>5.3

# %%
st[mask1]
# Out:
#     unmaed   0  gpa      iq  plament
# 0        0   0  6.8  .123.0        1
# 1        1   1  5.9  .160.0        0
# 3        3   3  7.4  .132.0        1
# 4        4   4  5.8  .142.0        0
# 12      12  12  6.1  .156.0        1
# 13      13  13  6.3  .156.0        1
# 14      14  14  6.7  .121.0        1
# 15      15  15  6.4  .153.0        1
# 16      16  16  7.1  .133.0        1
# 17      17  17  7.3  .159.0        1
# 18      18  18  6.5  .158.0        1
# 19      19  19  6.6  .159.0        1

# %%
mask2 = st['plament']==1

# %%
st[mask2]
# Out:
#     unmaed   0  gpa      iq  plament
# 0        0   0  6.8  .123.0        1
# 3        3   3  7.4  .132.0        1
# 12      12  12  6.1  .156.0        1
# 13      13  13  6.3  .156.0        1
# 14      14  14  6.7  .121.0        1
# 15      15  15  6.4  .153.0        1
# 16      16  16  7.1  .133.0        1
# 17      17  17  7.3  .159.0        1
# 18      18  18  6.5  .158.0        1
# 19      19  19  6.6  .159.0        1

# %%
st[mask1 & mask2]
# Out:
#     unmaed   0  gpa      iq  plament
# 0        0   0  6.8  .123.0        1
# 3        3   3  7.4  .132.0        1
# 12      12  12  6.1  .156.0        1
# 13      13  13  6.3  .156.0        1
# 14      14  14  6.7  .121.0        1
# 15      15  15  6.4  .153.0        1
# 16      16  16  7.1  .133.0        1
# 17      17  17  7.3  .159.0        1
# 18      18  18  6.5  .158.0        1
# 19      19  19  6.6  .159.0        1

# %%
st['plament'].value_counts()
# Out:
# plament
# 0    11
# 1    10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
st['plament'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='plament'>

# %%
st['plament'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
st['plament'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
myseries= st['plament'].value_counts()

# %%
myseries.head()
# Out:
# plament
# 0    11
# 1    10
# Name: count, dtype: int64

# %%
myseries.shape
# Out:
# (2,)

# %%
data['Phone 1'].value_counts()
# Out:
# Phone 1
# 229.077.5154              1
# 981-544-9452              1
# 874.617.5668x69878        1
# 001-927-965-8550x92406    1
# 581-440-6539              1
#                          ..
# 965-108-4406x20714        1
# +1-472-143-5037x884       1
# (752)776-3286             1
# +1-077-121-1558x0687      1
# (753)813-6941             1
# Name: count, Length: 100, dtype: int64

# %%
data['Phone 2'].value_counts()
# Out:
# Phone 2
# 397.884.0519x718          1
# +1-288-552-4666x060       1
# (399)820-6418x0071        1
# 001-243-038-4271x53076    1
# 9857827463                1
#                          ..
# 046.906.1442x6784         1
# 126.922.6153              1
# +1-472-021-4814x85074     1
# 264.742.7149              1
# 783.639.1472              1
# Name: count, Length: 100, dtype: int64

# %%
data['Phone 1'].value_counts()+data['Phone 2'].value_counts()
# Out:
# (026)401-7353x2417   NaN
# (041)737-3846        NaN
# (050)136-9025        NaN
# (092)508-0269        NaN
# (111)741-4173        NaN
#                       ..
# 975-998-1519         NaN
# 975.235.8921x269     NaN
# 981-544-9452         NaN
# 9857827463           NaN
# 999-728-1637         NaN
# Name: count, Length: 200, dtype: float64

# %%
data['First Name'].sort_values()
# Out:
# 5          Aimee
# 79     Alejandro
# 70    Alexandria
# 87        Alison
# 73         Anita
#          ...
# 12        Tracey
# 88        Vernon
# 68      Virginia
# 42         Wayne
# 98        Yvonne
# Name: First Name, Length: 100, dtype: object

# %%
data['First Name'].sort_values(ascending=False)
# Out:
# 98        Yvonne
# 42         Wayne
# 68      Virginia
# 88        Vernon
# 12        Tracey
#          ...
# 73         Anita
# 87        Alison
# 70    Alexandria
# 79     Alejandro
# 5          Aimee
# Name: First Name, Length: 100, dtype: object

# %% [markdown]
# # dataframes

# %%
data.sort_values('Last Name')
# Out:
#     Index      Customer Id First Name Last Name                    Company  \
# 67     68  a014Ec1b9FccC1E        Tom  Alvarado        Donaldson-Dougherty
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson      Ware, Burns and Oneal
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers              Lamb-Peterson
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter            Rasmussen Group
# 15     16  8cad0b4CBceaeec    Miranda   Beasley         Singleton and Sons
# ..    ...              ...        ...       ...                        ...
# 54     55  f3BEf3Be028166f      Robin      West  Nixon, Blackwell and Sosa
# 24     25  eC1927Ca84E033e      Shane    Wilcox                 Tucker LLC
# 86     87  ebe77E5Bf9476CE      Duane     Woods             Montoya-Miller
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young    Lee, Lucero and Johnson
# 76     77  BF6a1f9bd1bf8DE   Brittany    Zuniga               Mason-Hester
#
#                 City          Country              Phone 1  \
# ...

# %%
data.sort_values('Last Name',ascending=True,inplace=True)

# %%
data
# Out:
#     Index      Customer Id First Name Last Name                    Company  \
# 67     68  a014Ec1b9FccC1E        Tom  Alvarado        Donaldson-Dougherty
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson      Ware, Burns and Oneal
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers              Lamb-Peterson
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter            Rasmussen Group
# 15     16  8cad0b4CBceaeec    Miranda   Beasley         Singleton and Sons
# ..    ...              ...        ...       ...                        ...
# 54     55  f3BEf3Be028166f      Robin      West  Nixon, Blackwell and Sosa
# 24     25  eC1927Ca84E033e      Shane    Wilcox                 Tucker LLC
# 86     87  ebe77E5Bf9476CE      Duane     Woods             Montoya-Miller
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young    Lee, Lucero and Johnson
# 76     77  BF6a1f9bd1bf8DE   Brittany    Zuniga               Mason-Hester
#
#                 City          Country              Phone 1  \
# ...

# %%
data.sort_values(['First Name','Last Name','Index'],ascending=[True,False,True])
# Out:
#     Index      Customer Id  First Name Last Name                   Company  \
# 5       6  2d08FB17EE273F4       Aimee     Downs              Steele Group
# 79     80  A7F85c1DE4dB87f   Alejandro     Blair  Combs, Waller and Durham
# 70     71  CBCd2Ac8E3eBDF9  Alexandria      Buck             Keller-Coffey
# 87     88  E4Bbcd8AD81fC5f      Alison    Vargas   Vaughn, Watts and Leach
# 73     74  A3F76Be153Df4a3       Anita    Benson               Parrish Ltd
# ..    ...              ...         ...       ...                       ...
# 12     13  e35426EbDEceaFF      Tracey      Mata            Graham-Francis
# 88     89  efeb73245CDf1fF      Vernon      Kane         Carter-Strickland
# 68     69  421a109cABDf5fa    Virginia    Dudley                Warren Ltd
# 42     43  7E441b6B228DBcA       Wayne   Simpson           Perkins-Trevino
# 98     99  c23d1D9EE8DEB0A      Yvonne    Farmer        Fitzgerald-Harrell
#
# ...

# %%
st
# Out:
#     unmaed   0  gpa      iq  plament
# 0        0   0  6.8  .123.0        1
# 1        1   1  5.9  .160.0        0
# 2        2   2  5.3  .120.0        0
# 3        3   3  7.4  .132.0        1
# 4        4   4  5.8  .142.0        0
# 5        5   5  3.2  .122.0        0
# 6        6   6  2.1  .131.0        0
# 7        7   7  2.2  .162.0        0
# 8        8   8  4.5  .154.0        0
# 9        9   9  4.3  .167.0        0
# 10      10  10  3.1  .125.0        0
# 11      11  11  3.3  .137.0        0
# 12      12  12  6.1  .156.0        1
# 13      13  13  6.3  .156.0        1
# 14      14  14  6.7  .121.0        1
# 15      15  15  6.4  .153.0        1
# 16      16  16  7.1  .133.0        1
# 17      17  17  7.3  .159.0        1
# 18      18  18  6.5  .158.0        1
# 19      19  19  6.6  .159.0        1
# 20      20  20  3.5  .117.0        0

# %% [markdown]
# # drop dupli

# %%
st.drop_duplicates(['plament'])
# Out:
#    unmaed  0  gpa      iq  plament
# 0       0  0  6.8  .123.0        1
# 1       1  1  5.9  .160.0        0

# %%
data.head(2)
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 67     68  a014Ec1b9FccC1E        Tom  Alvarado    Donaldson-Dougherty
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
#
#                 City    Country             Phone 1            Phone 2  \
# 67  South Sophiaberg   Kiribati  (585)606-2980x2258  730-797-3594x5614
# 96      New Bradview  Sri Lanka               -3769       605.413.3198
#
#                             Email Subscription Date  \
# 67  nicholsonnina@montgomery.info         8/18/2020
# 96              vkemp@ferrell.com         7/10/2021
#
#                        Website
# 67     http://odom-massey.com/
# 96  https://novak-allison.com/

# %%
sector= data.groupby('Country')

# %%
sector

# %%
len(data)
# Out:
# 100

# %%
len(sector)
# Out:
# 85

# %%
sector.size().sort_values(ascending=False)
# Out:
# Country
# Solomon Islands                     4
# Zimbabwe                            2
# United Arab Emirates                2
# Saint Vincent and the Grenadines    2
# Dominican Republic                  2
#                                    ..
# Hungary                             1
# Honduras                            1
# Guyana                              1
# Guernsey                            1
# Mali                                1
# Length: 85, dtype: int64

# %%
sector.first()
# Out:
#                      Index      Customer Id First Name Last Name  \
# Country
# Albania                 25  eC1927Ca84E033e      Shane    Wilcox
# Algeria                 52  e898eEB1B9FE22b     Samuel  Crawford
# Anguilla                93  aAb6AFc7AfD0fF3     Collin     Ayers
# Antigua and Barbuda      3  6F94879bDAfE5a6        Roy     Berry
# Aruba                   99  c23d1D9EE8DEB0A     Yvonne    Farmer
# ...                    ...              ...        ...       ...
# Uzbekistan              47  300A40d3ce24bBA   Geoffrey    Guzman
# Vietnam                 12  CEDec94deE6d69B      Jenna    Dodson
# Western Sahara          17  a5DC21AE3a21eaA   Caroline     Foley
# Yemen                   89  efeb73245CDf1fF     Vernon      Kane
# Zimbabwe                73  F560f2d3cDFb618    Candice    Keller
#
#                                        Company               City  \
# Country
# Albania                             Tucker LLC         Bryanville
# ...

# %%
sector.last()
# Out:
#                      Index      Customer Id First Name Last Name  \
# Country
# Albania                 25  eC1927Ca84E033e      Shane    Wilcox
# Algeria                 52  e898eEB1B9FE22b     Samuel  Crawford
# Anguilla                93  aAb6AFc7AfD0fF3     Collin     Ayers
# Antigua and Barbuda      3  6F94879bDAfE5a6        Roy     Berry
# Aruba                   99  c23d1D9EE8DEB0A     Yvonne    Farmer
# ...                    ...              ...        ...       ...
# Uzbekistan              47  300A40d3ce24bBA   Geoffrey    Guzman
# Vietnam                 12  CEDec94deE6d69B      Jenna    Dodson
# Western Sahara          17  a5DC21AE3a21eaA   Caroline     Foley
# Yemen                   89  efeb73245CDf1fF     Vernon      Kane
# Zimbabwe                31  64DCcDFaB9DFd4e       Jack      Tate
#
#                                          Company               City  \
# Country
# Albania                               Tucker LLC         Bryanville
# ...

# %%
sector.groups
# Out:
# {'Albania': [24], 'Algeria': [51], 'Anguilla': [92], 'Antigua and Barbuda': [2], 'Aruba': [98], 'Bahamas': [34], 'Belarus': [49, 26], 'Belize': [35], 'Benin': [87], 'Bhutan': [90], 'Bolivia': [42], 'Bosnia and Herzegovina': [5], 'Bulgaria': [43, 7], 'Burkina Faso': [41], 'Canada': [69, 50], 'Chile': [0], 'Cyprus': [8], 'Denmark': [31], 'Djibouti': [1], 'Dominica': [78], 'Dominican Republic': [40, 3], 'Ecuador': [54], 'Ethiopia': [62], 'Fiji': [84], 'French Polynesia': [19], 'French Southern Territories': [68], 'Ghana': [47], 'Guernsey': [10], 'Guyana': [95], 'Honduras': [99], 'Hungary': [91], 'Iceland': [79], 'Iran': [70], 'Isle of Man': [82], 'Kiribati': [67], 'Kyrgyz Republic': [76], 'Lao People's Democratic Republic': [23], 'Liberia': [64], 'Liechtenstein': [32], 'Lithuania': [65], 'Madagascar': [53], 'Maldives': [86], 'Mali': [94], 'Malta': [20], 'Micronesia': [80], 'Monaco': [44], 'Montenegro': [38], 'Morocco': [71], 'Mozambique': [17], 'Myanmar': [77], 'Namibia': [89], 'Netherl
# ...

# %%
data.iloc[24,:]
# Out:
# Index                                            99
# Customer Id                         c23d1D9EE8DEB0A
# First Name                                   Yvonne
# Last Name                                    Farmer
# Company                          Fitzgerald-Harrell
# City                                Lake Elijahview
# Country                                       Aruba
# Phone 1                               (530)311-9786
# Phone 2                      001-869-452-0943x12424
# Email                mccarthystephen@horn-green.biz
# Subscription Date                         8/11/2021
# Website                        http://watkins.info/
# Name: 98, dtype: object

# %%
sector.get_group('Algeria').shape
# Out:
# (1, 12)

# %%
sector.sum()
# Out:
#                      Index                     Customer Id   First Name  \
# Country
# Albania                 25                 eC1927Ca84E033e        Shane
# Algeria                 52                 e898eEB1B9FE22b       Samuel
# Anguilla                93                 aAb6AFc7AfD0fF3       Collin
# Antigua and Barbuda      3                 6F94879bDAfE5a6          Roy
# Aruba                   99                 c23d1D9EE8DEB0A       Yvonne
# ...                    ...                             ...          ...
# Uzbekistan              47                 300A40d3ce24bBA     Geoffrey
# Vietnam                 12                 CEDec94deE6d69B        Jenna
# Western Sahara          17                 a5DC21AE3a21eaA     Caroline
# Yemen                   89                 efeb73245CDf1fF       Vernon
# Zimbabwe               104  F560f2d3cDFb61864DCcDFaB9DFd4e  CandiceJack
#
#                       Last Name                                    Company  \
# Country
# ...

# %%
st.head(5)
# Out:
#    unmaed  0  gpa      iq  plament
# 0       0  0  6.8  .123.0        1
# 1       1  1  5.9  .160.0        0
# 2       2  2  5.3  .120.0        0
# 3       3  3  7.4  .132.0        1
# 4       4  4  5.8  .142.0        0

# %%
pit= st.pivot_table(index=['unmaed'],columns= 'gpa',values='plament',aggfunc='mean')

# %%
pit
# Out:
# gpa     2.1  2.2  3.1  3.2  3.3  3.5  4.3  4.5  5.3  5.8  ...  6.1  6.3  6.4  \
# unmaed                                                    ...
# 0       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 1       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 2       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  0.0  NaN  ...  NaN  NaN  NaN
# 3       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 4       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  0.0  ...  NaN  NaN  NaN
# 5       NaN  NaN  NaN  0.0  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 6       0.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 7       NaN  0.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 8       NaN  NaN  NaN  NaN  NaN  NaN  NaN  0.0  NaN  NaN  ...  NaN  NaN  NaN
# 9       NaN  NaN  NaN  NaN  NaN  NaN  0.0  NaN  NaN  NaN  ...  NaN  NaN  NaN
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(pit)
# Out:
# <Axes: xlabel='gpa', ylabel='unmaed'>

# %%
data.corr
# Out:
# <bound method DataFrame.corr of     Index      Customer Id First Name Last Name                    Company  \
# 67     68  a014Ec1b9FccC1E        Tom  Alvarado        Donaldson-Dougherty
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson      Ware, Burns and Oneal
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers              Lamb-Peterson
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter            Rasmussen Group
# 15     16  8cad0b4CBceaeec    Miranda   Beasley         Singleton and Sons
# ..    ...              ...        ...       ...                        ...
# 54     55  f3BEf3Be028166f      Robin      West  Nixon, Blackwell and Sosa
# 24     25  eC1927Ca84E033e      Shane    Wilcox                 Tucker LLC
# 86     87  ebe77E5Bf9476CE      Duane     Woods             Montoya-Miller
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young    Lee, Lucero and Johnson
# 76     77  BF6a1f9bd1bf8DE   Brittany    Zuniga               Mason-Hester
#
# ...

# %% [markdown]
# # rename fun

# %%
df.head(2)
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                  5
# 1                                                  1
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 0                                                  1
# 1                                                  1
#
#    Have you been getting headaches more often than usual?  \
# ...

# %%
df.rename(columns={'Gender':'Gd'},inplace=True)

# %%
df
# Out:
#      Gd  Age  Have you recently experienced stress in your life?  \
# 0     0   20                                                  3
# 1     0   20                                                  2
# 2     0   20                                                  5
# 3     1   20                                                  3
# 4     0   20                                                  3
# ..   ..  ...                                                ...
# 838   0   21                                                  3
# 839   1   19                                                  3
# 840   1   19                                                  4
# 841   0   20                                                  5
# 842   0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# 1                                                    3
# ...

# %% [markdown]
# # set & reset inde

# %%
st.head(5)
# Out:
#    unmaed  0  gpa      iq  plament
# 0       0  0  6.8  .123.0        1
# 1       1  1  5.9  .160.0        0
# 2       2  2  5.3  .120.0        0
# 3       3  3  7.4  .132.0        1
# 4       4  4  5.8  .142.0        0

# %%
st.set_index('0',inplace=True)

# %%
st
# Out:
#     gpa      iq  plament
# 0
# 0   6.8  .123.0        1
# 1   5.9  .160.0        0
# 2   5.3  .120.0        0
# 3   7.4  .132.0        1
# 4   5.8  .142.0        0
# 5   3.2  .122.0        0
# 6   2.1  .131.0        0
# 7   2.2  .162.0        0
# 8   4.5  .154.0        0
# 9   4.3  .167.0        0
# 10  3.1  .125.0        0
# 11  3.3  .137.0        0
# 12  6.1  .156.0        1
# 13  6.3  .156.0        1
# 14  6.7  .121.0        1
# 15  6.4  .153.0        1
# 16  7.1  .133.0        1
# 17  7.3  .159.0        1
# 18  6.5  .158.0        1
# 19  6.6  .159.0        1
# 20  3.5  .117.0        0

# %%
st.reset_index()
# Out:
#      0  gpa      iq  plament
# 0    0  6.8  .123.0        1
# 1    1  5.9  .160.0        0
# 2    2  5.3  .120.0        0
# 3    3  7.4  .132.0        1
# 4    4  5.8  .142.0        0
# 5    5  3.2  .122.0        0
# 6    6  2.1  .131.0        0
# 7    7  2.2  .162.0        0
# 8    8  4.5  .154.0        0
# 9    9  4.3  .167.0        0
# 10  10  3.1  .125.0        0
# 11  11  3.3  .137.0        0
# 12  12  6.1  .156.0        1
# 13  13  6.3  .156.0        1
# 14  14  6.7  .121.0        1
# 15  15  6.4  .153.0        1
# 16  16  7.1  .133.0        1
# 17  17  7.3  .159.0        1
# 18  18  6.5  .158.0        1
# 19  19  6.6  .159.0        1
# 20  20  3.5  .117.0        0

# %%
st['gpa'].value_counts().reset_index()
# Out:
#     gpa  count
# 0   6.8      1
# 1   3.3      1
# 2   6.6      1
# 3   6.5      1
# 4   7.3      1
# 5   7.1      1
# 6   6.4      1
# 7   6.7      1
# 8   6.3      1
# 9   6.1      1
# 10  3.1      1
# 11  5.9      1
# 12  4.3      1
# 13  4.5      1
# 14  2.2      1
# 15  2.1      1
# 16  3.2      1
# 17  5.8      1
# 18  7.4      1
# 19  5.3      1
# 20  3.5      1

# %%
df
# Out:
#      Gd  Age  Have you recently experienced stress in your life?  \
# 0     0   20                                                  3
# 1     0   20                                                  2
# 2     0   20                                                  5
# 3     1   20                                                  3
# 4     0   20                                                  3
# ..   ..  ...                                                ...
# 838   0   21                                                  3
# 839   1   19                                                  3
# 840   1   19                                                  4
# 841   0   20                                                  5
# 842   0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# 1                                                    3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 26 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Gd                                                                    843 non-null    int64
#  1   Age                                                                   843 non-null    int64
#  2   Have you recently experienced stress in your life?                    843 non-null    int64
#  3   Have you noticed a rapid heartbeat or palpitations?                   843 non-null    int64
#  4   Have you been dealing with anxiety or tension recently?               843 non-null    int64
#  5   Do you face any sleep problems or difficulties falling asleep?        843 non-null    int64
# ...

# %%
df.dropna().shape
# Out:
# (843, 26)

# %%
df.shape
# Out:
# (843, 26)

# %%
data.shape
# Out:
# (100, 12)

# %%
data.dropna().shape
# Out:
# (100, 12)
